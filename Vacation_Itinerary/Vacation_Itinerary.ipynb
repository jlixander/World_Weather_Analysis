# %% [markdown]
# ## Deliverable 3. Create a Travel Itinerary Map.

# %%
# Dependencies and Setup
import pandas as pd
import requests
import gmaps
import gmaps.datasets

# Import API key
from config import g_key

# Configure gmaps
gmaps.configure(api_key=g_key)

# %%
# 1. Read the WeatherPy_vacation.csv into a DataFrame.
vacation_df = pd.read_csv("../Vacation_Search/WeatherPy_vacation.csv")
vacation_df.head()
# Out:
#    City_ID            City Country  Max Temp Current Description      Lat  \
# 0        3  Cabo San Lucas      MX     70.52           clear sky  22.8909
# 1        6      Bredasdorp      ZA     67.28          light rain -34.5322
# 2        7         Samarai      PG     78.62     overcast clouds -10.6167
# 3        8         Rikitea      PF     76.80          light rain -23.1203
# 4        9       Cape Town      ZA     74.12    scattered clouds -33.9258
#
#         Lng                         Hotel Name
# 0 -109.9124             Hotel Tesoro Los Cabos
# 1   20.0403           Bredasdorp Country Manor
# 2  150.6667                          Nuli Sapi
# 3 -134.9692                    People ThankYou
# 4   18.4232  Southern Sun Waterfront Cape Town

# %%
vacation_df.sort_values(by=['Country']).head(20)
# Out:
#      City_ID           City Country  Max Temp          Current Description  \
# 62       167      Abu Dhabi      AE     71.62                    clear sky
# 65       174          Sumbe      AO     76.33              overcast clouds
# 201      495           Soyo      AO     78.21                broken clouds
# 98       267         Namibe      AO     69.48              overcast clouds
# 26        58          Moron      AR     72.97                    clear sky
# 10        21  Mar Del Plata      AR     67.08                broken clouds
# 175      435         Viedma      AR     74.48                   few clouds
# 20        48         Rawson      AR     67.62                    clear sky
# 117      309       Necochea      AR     69.04                broken clouds
# 105      281       San Juan      AR     79.70                    clear sky
# 162      400    Warrnambool      AU     72.81              overcast clouds
# ...

# %%
# 2. Using the template add the city name, the country code, the weather description and maximum temperature for the city.
info_box_template = """
<dl>
<dt>Hotel Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
<dt>Weather</dt><dd>{Current Description}</dd>
<dt>Max Temp</dt><dd>{Max Temp}°F</dd>
</dl>
"""

# 3a. Get the data from each row and add it to the formatting template and store the data in a list.
hotel_info = [info_box_template.format(**row) for index, row in vacation_df.iterrows()]

# 3b. Get the latitude and longitude from each row and store in a new DataFrame.
locations = vacation_df[["Lat", "Lng"]]

# %%
# 4a. Add a marker layer for each city to the map.
locations = vacation_df[["Lat", "Lng"]]
max_temp = vacation_df["Max Temp"]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
heat_layer = gmaps.heatmap_layer(locations, weights=max_temp,dissipating=False,
             max_intensity=300, point_radius=4)

marker_layer = gmaps.marker_layer(locations, info_box_content=hotel_info)
fig.add_layer(heat_layer)
fig.add_layer(marker_layer)
# 4b. Display the figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# From the map above pick 4 cities and create a vacation itinerary route to travel between the four cities. 
# 5. Create DataFrames for each city by filtering the 'vacation_df' using the loc method. 
# Hint: The starting and ending city should be the same city.

vacation_start = vacation_df.loc[(vacation_df['Country']== 'AU') & (vacation_df['City']== 'Warrnambool')]
vacation_end = vacation_df.loc[(vacation_df['Country']== 'AU') & (vacation_df['City']== 'Warrnambool')]
vacation_stop1 = vacation_df.loc[(vacation_df['Country']== 'AU') & (vacation_df['City']== 'Mount Barker')]
vacation_stop2 = vacation_df.loc[(vacation_df['Country']== 'AU') & (vacation_df['City']== 'Toowoomba')] 
vacation_stop3 = vacation_df.loc[(vacation_df['Country']== 'AU') & (vacation_df['City']== 'Clarence Town')]

# %%
vacation_start
# Out:
#      City_ID         City Country  Max Temp Current Description      Lat  \
# 162      400  Warrnambool      AU     72.81     overcast clouds -38.3833
#
#           Lng       Hotel Name
# 162  142.4833  Lady Bay Resort

# %%
# 6. Get the latitude-longitude pairs as tuples from each city DataFrame using the to_numpy function and list indexing.
start = vacation_start.iloc[0,5:7].to_numpy()
end = vacation_end.iloc[0,5:7].to_numpy()
stop1 = vacation_stop1.iloc[0,5:7].to_numpy()
stop2 = vacation_stop2.iloc[0,5:7].to_numpy()
stop3 = vacation_stop3.iloc[0,5:7].to_numpy()

start
# Out:
# array([-38.3833, 142.4833], dtype=object)

# %%
# 7. Create a direction layer map using the start and end latitude-longitude pairs,
# and stop1, stop2, and stop3 as the waypoints. The travel_mode should be "DRIVING", "BICYCLING", or "WALKING".
fig = gmaps.figure()
start_to_end = gmaps.directions_layer(
    start, end, waypoints[stop1,stop2,stop3]), travel_mode = 'BICYCLING','DRIVING', 'WALKING')
fig.add_layer(start_to_end)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# 8. To create a marker layer map between the four cities.
#  Combine the four city DataFrames into one DataFrame using the concat() function.
itinerary_df = pd.concat([vacation_start, vacation_stop1, vacation_stop2, vacation_stop3, vacation_end],ignore_index=True)
itinerary_df
# Out:
#    City_ID           City Country  Max Temp Current Description      Lat  \
# 0      400    Warrnambool      AU     72.81     overcast clouds -38.3833
# 1      516   Mount Barker      AU     66.04     overcast clouds -35.0667
# 2      559      Toowoomba      AU     69.26          light rain -27.5500
# 3      514  Clarence Town      AU     83.14       broken clouds -32.5833
# 4      400    Warrnambool      AU     72.81     overcast clouds -38.3833
#
#         Lng                               Hotel Name
# 0  142.4833                          Lady Bay Resort
# 1  138.8667                A Suite Spot in the Hills
# 2  151.9667  Toowoomba Central Plaza Apartment Hotel
# 3  151.7833                      River Downs Cottage
# 4  142.4833                          Lady Bay Resort

# %%
# 9 Using the template add city name, the country code, the weather description and maximum temperature for the city. 
info_box_template = """
<dl>
<dt>Hotel Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
<dt>Weather</dt><dd>{Current Description}</dd>
<dt>Max Temp</dt><dd>{Max Temp}°F</dd>
</dl>
"""

# 10a Get the data from each row and add it to the formatting template and store the data in a list.
hotel_info = [info_box_template.format(**row) for index, row in itinerary_df.iterrows()]

# 10b. Get the latitude and longitude from each row and store in a new DataFrame.
locations = itinerary_df[["Lat", "Lng"]]

# %%
# 11a. Add a marker layer for each city to the map.
locations = itinerary_df[["Lat", "Lng"]]
max_temp = itinerary_df["Max Temp"]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
heat_layer = gmaps.heatmap_layer(locations, weights=max_temp,dissipating=False,
             max_intensity=300, point_radius=4)

marker_layer = gmaps.marker_layer(locations, info_box_content=hotel_info)
fig.add_layer(heat_layer)
fig.add_layer(marker_layer)

# 11b. Display the figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
